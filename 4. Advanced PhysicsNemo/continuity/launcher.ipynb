# %% [markdown]
# ## Plain, $\beta = 1$, FullyConnected

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./continuity.py\
    --config-name 'config_beta1_ffc' \
    |& tee -a ./logs/continuity_beta1_ffc.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W406 08:22:11.995641193 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W406 08:22:11.995677433 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [08:22:11] - JIT using the NVFuser TorchScript backend
# [08:22:11] - Disabling JIT because functorch does not work with it.
# [08:22:11] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...

# %% [markdown]
# ## Plain, $\beta = 1$, FourierNet

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./continuity.py\
    --config-name 'config_beta1' \
    |& tee -a ./logs/continuity_beta1.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W405 14:57:44.202557781 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W405 14:57:44.202599291 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [14:57:44] - JIT using the NVFuser TorchScript backend
# [14:57:44] - Disabling JIT because functorch does not work with it.
# [14:57:44] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...

# %% [markdown]
# ## Complex setting: $\beta = 30$

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./continuity.py\
    --config-name 'config_beta30_ffc' \
    |& tee -a ./logs/continuity_beta30_ffc.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W406 08:34:48.626578316 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W406 08:34:48.626618516 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [08:34:48] - JIT using the NVFuser TorchScript backend
# [08:34:48] - Disabling JIT because functorch does not work with it.
# [08:34:48] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...
