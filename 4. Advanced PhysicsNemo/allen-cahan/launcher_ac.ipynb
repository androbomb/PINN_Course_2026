# %% [markdown]
# ## Base

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./allen-cahan.py\
    --config-name 'config_ac' \
    |& tee -a ./logs/allen-cahan.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W406 09:03:05.564154535 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W406 09:03:05.564190385 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [09:03:05] - JIT using the NVFuser TorchScript backend
# [09:03:05] - Disabling JIT because functorch does not work with it.
# [09:03:05] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...

# %% [markdown]
# ## Base, Causal Loss

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./allen-cahan-causal-loss.py\
    --config-name 'config_ac' \
    |& tee -a ./logs/allen-cahan-causal-loss.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W105 17:14:05.674908916 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W105 17:14:05.674941935 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [17:14:05] - JIT using the NVFuser TorchScript backend
# [17:14:05] - Disabling JIT because functorch does not work with it.
# [17:14:05] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...

# %% [markdown]
# ## Base, Fourier

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./allen-cahan-fourier.py\
    --config-name 'config_ac' \
    |& tee -a ./logs/allen-cahan-fourier.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W331 08:10:25.289695295 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W331 08:10:25.289728384 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [08:10:25] - JIT using the NVFuser TorchScript backend
# [08:10:25] - Disabling JIT because functorch does not work with it.
# [08:10:25] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...

# %% [markdown]
# ## Basic MoE model

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./allen-cahan-MoE.py\
    --config-name 'config_ac' \
    |& tee -a ./logs/allen-cahan-MoE.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W1229 17:10:05.266353298 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W1229 17:10:05.266389947 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [17:10:05] - JIT using the NVFuser TorchScript backend
# [17:10:05] - Disabling JIT because functorch does not work with it.
# [17:10:05] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...

# %% [markdown]
# ## Full MoE Model

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./allen-cahan-MoE-fourier.py\
    --config-name 'config_NTK' \
    |& tee -a ./logs/allen-cahan-MoE-fourier.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W1230 10:33:50.522248952 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W1230 10:33:50.522299631 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [10:33:50] - JIT using the NVFuser TorchScript backend
# [10:33:50] - Disabling JIT because functorch does not work with it.
# [10:33:50] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...
