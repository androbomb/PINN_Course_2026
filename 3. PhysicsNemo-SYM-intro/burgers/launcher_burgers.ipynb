# %% [markdown]
# # Plain Burger training

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./burgers.py\
    --config-name 'config_burgers' \
    |& tee -a ./logs/burgers.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W1229 16:37:12.124245165 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W1229 16:37:12.124276304 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [16:37:12] - JIT using the NVFuser TorchScript backend
# [16:37:12] - Disabling JIT because functorch does not work with it.
# [16:37:12] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...

# %% [markdown]
# # Using ReLOBralo and LBFGS

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    export OC_CAUSE=1 && \
    python3 \
    ./burgers.py\
    --config-name 'config_burgers_LBFGS_relobralo' \
    |& tee -a ./logs/burgers.txt\
)
# Out:
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [W1229 16:46:29.799200673 init.cpp:779] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_single_node_mode is deprecated and a no-op (function operator())
# [W1229 16:46:29.799239862 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [16:46:29] - JIT using the NVFuser TorchScript backend
# [16:46:29] - Disabling JIT because functorch does not work with it.
# [16:46:29] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# ...
